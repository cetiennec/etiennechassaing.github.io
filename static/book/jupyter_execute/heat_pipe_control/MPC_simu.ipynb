# %%
import numpy as np
from PipeEnv import PipeHeaterSafeEnvGymnasium
from MPCCon import MPCController
from params import *
import matplotlib.pyplot as plt

params["N"] = 30
env = PipeHeaterSafeEnvGymnasium(params, Tinlet=15.0, Tset= 85.0, T_ext=10.0, dt=1.0, t_final=3600)

mpc_dt = 10.0
mpc = MPCController(params, dt=mpc_dt, Hp=80, Q=[0.0, 1e3], R=1e-5, Rd=1.0, T_set=[92.0, 85.0], T_safety=95.0, ramped = True)

obs, _ = env.reset()

# %%
# the env exposes self.T inside; we assume we can access env.T for full state (otherwise use estimator)
x = env.T.copy()
u_prev = 0.0
traj = []
mpc_steps = int(mpc.dt / env.dt)   # number of env steps per MPC update
setpoints = []

for step in range(3600):
    # Update MPC only every mpc_steps
    if step % mpc_steps == 0:
        u_cmd, T_in_sp, T_out_sp = mpc.compute_action(x0=x, u_prev=u_prev)
        u_prev = u_cmd  # store for move suppression, rate constraints, etc.

    # Apply the most recent MPC command
    action = np.array([u_cmd], dtype=np.float32)
    obs, reward, terminated, truncated, info = env.step(action)

    # Save state
    x = env.T.copy()
    traj.append((step, x.copy(), u_cmd, reward))
    setpoints.append((T_in_sp, T_out_sp))

    if terminated:
        break


# now traj contains the run; you can plot Toutlet (x[-1]) over time, etc.
# Unpack trajectory
steps = [t[0]/60 for t in traj]
T_out = [t[1][-1] for t in traj]   # last element of state is outlet temperature
T_in = [t[1][0] for t in traj]   # last element of state is outlet temperature
u_cmds = [t[2] for t in traj]
rewards = [t[3] for t in traj]

T_in_sp = [t[0] for t in setpoints]   # last element of state is outlet temperature
T_out_sp = [t[1] for t in setpoints]   # last element of state is outlet temperature

# Create subplots with different heights
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(12, 8),
    sharex=True,
    gridspec_kw={"height_ratios": [2, 1]}  # top bigger than bottom
)

# --- Subplot 1: Outlet Temperature ---
ax1.plot(steps, T_in, label="Inlet Temperature")
ax1.plot(steps, T_out, label="Outlet Temperature")
ax1.plot(steps, T_out_sp, color="green", linestyle="-.", label="Setpoint")
ax1.axhline(mpc.T_safety, color="red", linestyle="--", label="Safety Limit")

ax1.set_ylabel("Temperature [°C]")
ax1.set_title("MPC Control of Pipe Heater - Outlet Temperature")
ax1.legend(loc="best")
ax1.grid(True)

# --- Subplot 2: Control Input ---
ax2.plot(steps, u_cmds, label="Heater Power (kW)")
ax2.set_xlabel("Time [min]")
ax2.set_ylabel("Heater Command [kW]")
ax2.set_title("MPC Control Input")
ax2.legend(loc="best")
ax2.grid(True)

plt.tight_layout()

# Save both subplots together
plt.savefig("images/ramp_MPC_results.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 for step in range(3600):
#       9     # Update MPC only every mpc_steps
#      10     if step % mpc_steps == 0:
# ---> 11         u_cmd, T_in_sp, T_out_sp = mpc.compute_action(x0=x, u_prev=u_prev)
#      12         u_prev = u_cmd  # store for move suppression, rate constraints, etc.
#      14     # Apply the most recent MPC command
#
# File ~/PycharmProjects/localBook/mybook/heat_pipe_control/MPCCon.py:184, in MPCController.compute_action(self, x0, u_prev, ramped)
#     182 prob = cp.Problem(cp.Minimize(obj), constraints)
#     183 # prob.solve(solver=cp.ECOS, verbose=True)
# --> 184 prob.solve(
#     185     solver=cp.OSQP,
#     186     warm_start=True,
#     187     verbose=False,
#     188     eps_abs=1e-6,  # tighter absolute feasibility tolerance
#     189     eps_rel=1e-6,  # tighter relative tolerance
#     190     max_iter=100000,
#     191 )  # allow more iterations to reach stricter tolerance)
#     193 if self.u_var.value is None:
#     194     u0 = float(np.clip(u_prev, 0.0, 33.0))
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/problems/problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/problems/problem.py:1191, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1188         self.unpack(chain.retrieve(soln))
#    1189         return self.value
# -> 1191 data, solving_chain, inverse_data = self.get_problem_data(
#    1192     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1193 )
#    1195 if verbose:
#    1196     print(_NUM_SOLVER_STR)
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/problems/problem.py:805, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     802     s.LOGGER.info(
#     803              'Compiling problem (target solver=%s).', solver_name)
#     804     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 805 data, inverse_data = solving_chain.apply(self, verbose)
#     806 safe_to_cache = (
#     807     isinstance(data, dict)
#     808     and s.PARAM_PROB in data
#     809     and not any(isinstance(reduction, EvalParams)
#     810                 for reduction in solving_chain.reductions)
#     811 )
#     812 self._compilation_time = time.time() - start
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/reductions/qp2quad_form/qp_matrix_stuffing.py:283, in QpMatrixStuffing.apply(self, problem)
#     281 # Batch expressions together, then split apart.
#     282 expr_list = [arg for c in ordered_cons for arg in c.args]
# --> 283 params_to_Ab = extractor.affine(expr_list)
#     285 inverse_data.minimize = type(problem.objective) == Minimize
#     286 variables = problem.variables()
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/utilities/coeff_extractor.py:72, in CoeffExtractor.affine(self, expr)
#      70 num_rows = sum([e.size for e in expr_list])
#      71 op_list = [e.canonical_form[0] for e in expr_list]
# ---> 72 return canonInterface.get_problem_matrix(op_list,
#      73                                          self.x_length,
#      74                                          self.id_map,
#      75                                          self.param_to_size,
#      76                                          self.param_id_map,
#      77                                          num_rows,
#      78                                          self.canon_backend)
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/cvxcore/python/canonInterface.py:296, in get_problem_matrix(linOps, var_length, id_to_col, param_to_size, param_to_col, constr_length, canon_backend)
#     294 if canon_backend == s.CPP_CANON_BACKEND:
#     295     from cvxpy.cvxcore.python.cppbackend import build_matrix
# --> 296     return build_matrix(id_to_col, param_to_size, param_to_col, var_length, constr_length, linOps)
#     298 elif canon_backend in {s.SCIPY_CANON_BACKEND, s.RUST_CANON_BACKEND,
#     299                        s.NUMPY_CANON_BACKEND}:
#     300     param_size_plus_one = sum(param_to_size.values())
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/cvxcore/python/cppbackend.py:60, in build_matrix(id_to_col, param_to_size, param_to_col, var_length, constr_length, linOps)
#      57     tree = linPy_to_linC[lin]
#      58     lin_vec.push_back(tree)
# ---> 60 problemData = cvxcore.build_matrix(
#      61     lin_vec, int(var_length), id_to_col_C, param_to_size_C, s.get_num_threads()
#      62 )
#      64 # Populate tensors with info from problemData.
#      65 tensor_V = {}
#
# File ~/PycharmProjects/localBook/.venv/lib/python3.11/site-packages/cvxpy/cvxcore/python/cvxcore.py:993, in build_matrix(*args)
#     992 def build_matrix(*args):
# --> 993     return _cvxcore.build_matrix(*args)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# Convert trajectory data to DataFrame
df = pd.DataFrame({
    "time_min": steps,
    "Tinlet": T_in,
    "Toutlet": T_out,
    "HeaterPower_kW": u_cmds,
    "reward": rewards,
})

# Save to CSV
csv_filename = "results/MPC_run_data_ramp.csv"
df.to_csv(csv_filename, index=False)

print(f"Saved results to {csv_filename}")
# Out:
# Saved results to results/MPC_run_data_ramp.csv

# %%
N=3000
x = env.T.copy()
traj_env = []
mpc_dt = 10.0
H = N/mpc_dt

env = PipeHeaterSafeEnvGymnasium(params, Tinlet=15.0, Tset=85.0, T_ext=10.0, dt=1.0, t_final=N)
mpc = MPCController(params, dt=mpc_dt, Hp=70, Q=100.0, R=1e-8, Rd=1.0, T_set=92.0, T_safety=95.0)

for step in range(N):
    u_cmd = 30  # step input
    action = np.array([u_cmd], dtype=np.float32)
    obs, reward, terminated, truncated, info = env.step(action)
    x = env.T.copy()
    traj_env.append((step, x.copy(), u_cmd, reward))
    if terminated:
        break
 
steps_env = [t[0] for t in traj_env]    
T_out = [t[1][-1] for t in traj_env]   # last element of state is outlet temperature
T_in = [t[1][0] for t in traj_env]   # last element of state is outlet temperature
# Define step sequence of length Hp
u_seq = np.ones(mpc.Hp) * 30  

# Initial state (same as env start)
x0 = np.ones(np.shape(mpc.B)) * 15  

# Predict using MPC internal model
X_pred = mpc._predict_trajectory(x0, u_seq)
time_mpc = np.arange(len(X_pred)) * mpc.dt

plt.figure()
plt.plot(steps_env, T_in, label="$T_{inlet}$ full model")
plt.plot(steps_env, T_out, label="$T_{outlet}$ full modele")

plt.plot(time_mpc, X_pred[:,0], '--', label="$T_{inlet}$ MPC prediction")
plt.plot(time_mpc, X_pred[:,-1], '--', label="$T_{outlet}$ MPC prediction")

plt.xlabel("time (s)")
plt.ylabel("Temperature in °C")
plt.legend()
plt.grid()
plt.savefig("images/MPC_vs_full_model.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 8
#       5 H = N/mpc_dt
#       7 env = PipeHeaterSafeEnvGymnasium(params, Tinlet=15.0, Tset=85.0, T_ext=10.0, dt=1.0, t_final=N)
# ----> 8 mpc = MPCController(params, dt=mpc_dt, Hp=70, Q=100.0, R=1e-8, Rd=1.0, T_set=92.0, T_safety=95.0)
#      10 for step in range(N):
#      11     u_cmd = 30  # step input
#
# File ~/PycharmProjects/NehemisControl/mybook/MPCCon.py:38, in MPCController.__init__(self, params, dt, Hp, Q, R, Rd, T_set, T_safety, verbose)
#      36 self.N = params["N"]
#      37 self.Hp = Hp
# ---> 38 self.Q = np.diag(Q)
#      39 self.R = R
#      40 self.Rd = Rd
#
# File ~/PycharmProjects/NehemisControl/.venv/lib/python3.10/site-packages/numpy/lib/_twodim_base_impl.py:315, in diag(v, k)
#     313     return diagonal(v, k)
#     314 else:
# --> 315     raise ValueError("Input must be 1- or 2-d.")
#
# ValueError: Input must be 1- or 2-d.
